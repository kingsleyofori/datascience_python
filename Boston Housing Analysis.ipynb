# %% [markdown]
# # **BOSTON HOUSING ANALYSIS**
#
# This project seeks to understand the infamous Boston Housing Market Dataset.

# %%
# Importation of relevant libraries and dependencies
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston

# %matplotlib inline
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading in the dataset
boston = load_boston()

# Calling the loaded dataset
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
# A quick summary of the dataset output above
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
# Data Output
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
# Targets Output
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
# Feature Names
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
# Placing the dataset in a dataframe
boston_features = pd.DataFrame(boston.data, columns=boston.feature_names)

# %%
# Placing the target variable in a proper dataframe
boston_target = pd.DataFrame(boston.target, columns=['target'])

# %%
# Join the two dataset together
df = pd.concat([boston_features, boston_target], axis=1)

# %%
# Calling the full dataset
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
# A descriptive summary of the dataset
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Checking if there are null counts in the columns
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
# Verifying if there are duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# Correlation of the independent variables and predictors
corr = df.corr()
corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# Visualization of the correlation using heatmaps
plt.figure(figsize=(10,5), dpi=200)
sns.heatmap(corr, annot=True, cmap='coolwarm', cbar=False)

# %% [markdown]
# * It seems most of independent variables has a negative relationship with the target varible.
# * Going forward, the positive independent variables will be considered for the modelling or prediction of prices.
# * 'ZN', 'CHAS',  'RM', 'DIS', and 'B' will be used in the price determination.

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.LSTAT)
plt.title('Relationship between target and LSTAT')
# Out:
# Text(0.5, 1.0, 'Relationship between target and LSTAT')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.B)
plt.title('Relationship between target and B')
# Out:
# Text(0.5, 1.0, 'Relationship between target and B')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.RAD)
plt.title('Relationship between target and RAD')
# Out:
# Text(0.5, 1.0, 'Relationship between target and RAD')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.DIS)
plt.title('Relationship between target and DIS')
# Out:
# Text(0.5, 1.0, 'Relationship between target and DIS')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.AGE)
plt.title('Relationship between target and AGE')
# Out:
# Text(0.5, 1.0, 'Relationship between target and AGE')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.RM)
plt.title('Relationship between target and RM')
# Out:
# Text(0.5, 1.0, 'Relationship between target and RM')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.CHAS)
plt.title('Relationship between target and CHAS')
# Out:
# Text(0.5, 1.0, 'Relationship between target and CHAS')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.ZN)
plt.title('Relationship between target and ZN')
# Out:
# Text(0.5, 1.0, 'Relationship between target and ZN')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.CRIM)
plt.title('Relationship between target and CRIM')
# Out:
# Text(0.5, 1.0, 'Relationship between target and CRIM')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.boxplot(x=df.target)
plt.title('Boxplot of Target')
# Out:
# Text(0.5, 1.0, 'Boxplot of Target')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.NOX)
plt.title('Relationship between target and NOX')
# Out:
# Text(0.5, 1.0, 'Relationship between target and NOX')

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.scatterplot(y=df.target,x=df.INDUS)
plt.title('Relationship between target and INDUS')
# Out:
# Text(0.5, 1.0, 'Relationship between target and INDUS')

# %%
df.hist(bins=50, figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff8c31edb10>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.histplot(df['target'])

# %%
# Building up a model
attributes = ['ZN','CHAS', 'RM', 'DIS', 'B']

# %%
X = df[attributes]
y = df['target']

# %%
X.head()
# Out:
#      ZN  CHAS     RM     DIS       B
# 0  18.0   0.0  6.575  4.0900  396.90
# 1   0.0   0.0  6.421  4.9671  396.90
# 2   0.0   0.0  7.185  4.9671  392.83
# 3   0.0   0.0  6.998  6.0622  394.63
# 4   0.0   0.0  7.147  6.0622  396.90

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: target, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 15, test_size=0.12)

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(X_test,y_test)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X_test)

# %%
y_pred
# Out:
# array([25.32491836, 38.62626981, 14.97399929, 18.71946255, 24.38828724,
#         9.06270049, 16.82361246,  7.64035216, 25.30194912, 17.00297782,
#        21.07078939, 19.85712894, 20.01715241, 16.91432451, 19.06050759,
#        12.62868186, 12.19408919, 13.66285288, 19.6336142 , 16.71613956,
#        31.22306642, 13.94342424, 19.9073869 , 21.81554661, 18.71090022,
#        16.61812018, 25.41219065, 18.76735308, 21.08774029, 25.70835907,
#        21.95902797,  9.2127331 , 20.11774318, 17.26789748, 21.67165671,
#        12.7851549 , 19.44294785, 15.26554776, 22.02388435, 19.94273636,
#        39.72071129, 33.70903445, 20.15252779, 24.23810688, 26.1233485 ,
#        20.0718187 , 16.98748526, 27.61617902, 27.24372679, 24.66978582,
#        33.56260783, 10.70798252, 15.65503022, 12.86992632, 18.5502401 ,
#        32.25148858, 13.03567785, 27.45164794, 17.89583309, 24.91132395,
#        12.8722899 ])

# %%
y_test
# Out:
# 301    22.0
# 262    48.8
# 172    23.1
# 505    11.9
# 111    22.8
#        ...
# 404     8.5
# 482    25.0
# 475    13.3
# 504    22.0
# 474    13.8
# Name: target, Length: 61, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

MSE = mean_squared_error(y_test, y_pred)
MSE
# Out:
# 20.300544891693438

# %%
df.target.describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: target, dtype: float64

# %%
MAE = mean_absolute_error(y_test, y_pred)
MAE
# Out:
# 3.487280810886027

# %%
(3.487280810886027/22.532806)*100
# Out:
# 15.476460458968255

# %% [markdown]
# * We are literally off by 15% from the average target value which is somehow not that bad and with a test accuracy of 69%.

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.6943140361039899

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(y_test, y_pred)
# Out:
# 0.6943140361039899

# %%
plt.figure(figsize=(15,15),dpi=150)
plt.scatter(y_test, y_pred)
plt.plot(y_test, y_test, color='r')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted prices")
plt.title("Actual prices vs Predicted prices")
# Out:
# Text(0.5, 1.0, 'Actual prices vs Predicted prices')
