# %% [markdown]
# Housing - New - Dataset
# * About Dataset
# This is a dataset containing Housing details. This Dataset can be used to apply Principal Component Analysis Technique and check it's usage and applications.The dataset contains various attributes of the houses like area,price,stories,rooms etc.
#
# * Dataset
# This dataset can be found [HERE](https://www.kaggle.com/datasets/shrutipandit707/housingnewdataset)

# %%
# File Path
file_path = '../Housing Prices Project/newhousing.csv'

# %%
#importation of relevant libraries
import pyforest

# %%
#Loading in the data
file = pd.read_csv(file_path)

# %%
file.head()
# Out:
#      price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  5250000  5500         3          2        1         1          0         1
# 1  4480000  4040         3          1        2         1          0         0
# 2  3570000  3640         2          1        1         1          0         0
# 3  2870000  3040         2          1        1         0          0         0
# 4  3570000  4500         2          1        1         0          0         0
#
#    hotwaterheating  airconditioning  parking  prefarea  semi-furnished  \
# 0                0                0        0         0               1
# 1                0                0        1         0               1
# 2                0                0        0         0               0
# 3                0                0        0         0               0
# 4                0                0        0         0               0
#
#    unfurnished  areaperbedroom   bbratio
# ...

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            545 non-null    int64
#  1   area             545 non-null    int64
#  2   bedrooms         545 non-null    int64
#  3   bathrooms        545 non-null    int64
#  4   stories          545 non-null    int64
#  5   mainroad         545 non-null    int64
#  6   guestroom        545 non-null    int64
#  7   basement         545 non-null    int64
#  8   hotwaterheating  545 non-null    int64
#  9   airconditioning  545 non-null    int64
#  10  parking          545 non-null    int64
#  11  prefarea         545 non-null    int64
#  12  semi-furnished   545 non-null    int64
#  13  unfurnished      545 non-null    int64
#  14  areaperbedroom   545 non-null    float64
#  15  bbratio          545 non-null    float64
# dtypes: float64(2), int64(14)
# memory usage: 68.2 KB

# %%
file.duplicated().sum()
# Out:
# 0

# %%
file.eq(0).sum()
# Out:
# price                0
# area                 0
# bedrooms             0
# bathrooms            0
# stories              0
# mainroad            77
# guestroom          448
# basement           354
# hotwaterheating    520
# airconditioning    373
# parking            299
# prefarea           417
# semi-furnished     318
# unfurnished        367
# areaperbedroom       0
# bbratio              0
# dtype: int64

# %%
file.describe().T
# Out:
#                  count          mean           std           min  \
# price            545.0  4.766729e+06  1.870440e+06  1.750000e+06
# area             545.0  5.150541e+03  2.170141e+03  1.650000e+03
# bedrooms         545.0  2.965138e+00  7.380639e-01  1.000000e+00
# bathrooms        545.0  1.286239e+00  5.024696e-01  1.000000e+00
# stories          545.0  1.805505e+00  8.674925e-01  1.000000e+00
# mainroad         545.0  8.587156e-01  3.486347e-01  0.000000e+00
# guestroom        545.0  1.779817e-01  3.828487e-01  0.000000e+00
# basement         545.0  3.504587e-01  4.775519e-01  0.000000e+00
# hotwaterheating  545.0  4.587156e-02  2.093987e-01  0.000000e+00
# airconditioning  545.0  3.155963e-01  4.651799e-01  0.000000e+00
# parking          545.0  6.935780e-01  8.615858e-01  0.000000e+00
# prefarea         545.0  2.348624e-01  4.243022e-01  0.000000e+00
# semi-furnished   545.0  4.165138e-01  4.934337e-01  0.000000e+00
# ...

# %%
file.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'semi-furnished', 'unfurnished',
#        'areaperbedroom', 'bbratio'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Number of Bedrooms in the House')
sns.countplot(file['bedrooms'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Number of Bedrooms in the House'}, xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Number of Bathrooms in the House')
sns.countplot(file['bathrooms'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Number of Bathrooms in the House'}, xlabel='bathrooms', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Number of Stories in the House')
sns.countplot(file['stories'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Number of Stories in the House'}, xlabel='stories', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Houses near Main Road vs those which are not')
sns.countplot(file['mainroad'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Houses near Main Road vs those which are not'}, xlabel='mainroad', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Number of Guestroom in the House')
sns.countplot(file['guestroom'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Number of Guestroom in the House'}, xlabel='guestroom', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Houses with Basement and those without')
sns.countplot(file['basement'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Houses with Basement and those without'}, xlabel='basement', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Houses with Hot Water Heating and those without')
sns.countplot(file['hotwaterheating'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Houses with Hot Water Heating and those without'}, xlabel='hotwaterheating', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Houses with airconditioning and those without')
sns.countplot(file['airconditioning'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Houses with airconditioning and those without'}, xlabel='airconditioning', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Is house unfurnished?')
sns.countplot(file['unfurnished'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Is house unfurnished?'}, xlabel='unfurnished', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Is house semi-furnished?')
sns.countplot(file['semi-furnished'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Is house semi-furnished?'}, xlabel='semi-furnished', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Houses with Prefabricated Area and those without')
sns.countplot(file['prefarea'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Houses with Prefabricated Area and those without'}, xlabel='prefarea', ylabel='count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
plt.title('Houses with Parking Lot and those without')
sns.countplot(file['parking'])
# Out:
# c:\Users\Ofori Kingsley\AppData\Local\Programs\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Houses with Parking Lot and those without'}, xlabel='parking', ylabel='count'>

# %%
file.corr()
# Out:
#                     price      area  bedrooms  bathrooms   stories  mainroad  \
# price            1.000000  0.535997  0.366494   0.517545  0.420712  0.296898
# area             0.535997  1.000000  0.151858   0.193820  0.083996  0.288874
# bedrooms         0.366494  0.151858  1.000000   0.373930  0.408564 -0.012033
# bathrooms        0.517545  0.193820  0.373930   1.000000  0.326165  0.042398
# stories          0.420712  0.083996  0.408564   0.326165  1.000000  0.121706
# mainroad         0.296898  0.288874 -0.012033   0.042398  0.121706  1.000000
# guestroom        0.255517  0.140297  0.080549   0.126469  0.043538  0.092337
# basement         0.187057  0.047417  0.097312   0.102106 -0.172394  0.044002
# hotwaterheating  0.093073 -0.009229  0.046049   0.067159  0.018847 -0.011781
# airconditioning  0.452954  0.222393  0.160603   0.186915  0.293602  0.105423
# parking          0.384394  0.352980  0.139270   0.177496  0.045547  0.204433
# ...

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.heatmap(file.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.histplot(file['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=(10,5),dpi=150)
sns.scatterplot(data=file, x='price', y='area');

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.boxplot(data=file, x='bedrooms', y='price');

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.boxplot(data=file, x='bathrooms', y='price');

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.boxplot(data=file, x='stories', y='price');

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.boxplot(data=file, x='mainroad', y='price');

# %%
# Split data into features and labels
file.columns
features = ['area', 'bedrooms', 'bathrooms','stories', 'mainroad']

# %%
X = file[features]
y = file.price

# %%
X.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad
# 0  5500         3          2        1         1
# 1  4040         3          1        2         1
# 2  3640         2          1        1         1
# 3  3040         2          1        1         0
# 4  4500         2          1        1         0

# %%
y.head()
# Out:
# 0    5250000
# 1    4480000
# 2    3570000
# 3    2870000
# 4    3570000
# Name: price, dtype: int64

# %%
# Building up a Model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=5, test_size=0.15)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X.shape, X_train.shape, X_test.shape
# Out:
# ((545, 5), (463, 5), (82, 5))

# %%
y.shape, y_train.shape, y_test.shape
# Out:
# ((545,), (463,), (82,))

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression().fit(X_train, y_train)

# %%
y_pred = lr_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test,y_pred)
MSE = np.sqrt(MSE)
print('Mean Squared Error:', MSE)
# Out:
# Mean Squared Error: 1404153.0553805246

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 1011138.0225338694

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(y_test, y_pred)
# Out:
# 0.4925106372771024

# %% [markdown]
# * The best possible value is 1.0 and ours is around 0.49. This is really bad.
# * This explains why the true values and predictions are far away from each other during the visualization.

# %%
file['price'].describe()
# Out:
# count    5.450000e+02
# mean     4.766729e+06
# std      1.870440e+06
# min      1.750000e+06
# 25%      3.430000e+06
# 50%      4.340000e+06
# 75%      5.740000e+06
# max      1.330000e+07
# Name: price, dtype: float64

# %%
4.766729e+06
# Out:
# 4766729.0

# %%
(1011138/4766729)*100
# Out:
# 21.212407921658645

# %% [markdown]
# If we look at the ratio of MAE to average price of the house, we are off by around 21%. This is not Great, but not horrible either.

# %%
plt.figure(figsize=(15,15),dpi=150)
plt.scatter(y_test, y_pred)
plt.plot(y_test, y_test, color='r')
plt.xlabel("Actual Prices")
plt.ylabel("Predicted prices")
plt.title("Actual prices vs Predicted prices")
# Out:
# Text(0.5, 1.0, 'Actual prices vs Predicted prices')

# %%
lr_model.score(X_test, y_test)
# Out:
# 0.49247910309134457
